# %% [markdown]
# <a href="https://colab.research.google.com/github/Jleeh66/AI-CHOSUN/blob/main/Firstpy_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 첫 번째 파이썬 프로그램

# %%
print("Hello Python")
# Out:
# Hello python
